# %%
import qiskit.qasm2

# %%
first_circuit = qiskit.qasm2.load("first_circuit.qasm")

# %%
first_circuit.draw('mpl')

# %%
first_circ_encdoded = qiskit.qasm2.load("First_encoded.qasm")

# %%
first_circ_encdoded.draw('mpl')
